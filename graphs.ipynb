# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Input Laplace with Base Model (Base Model at 6 as placeholder for "No Privacy")
epsilons_with_base_input = [0.1, 1, 5, 6]

# MRI-PET Input Laplace metrics
psnr_mri_values_input_laplace = [9.3095, 9.1002, 9.1666]
psnr_pet_values_input_laplace = [9.4445, 9.6638, 9.8249]
ssim_mri_values_input_laplace = [0.0235, 0.0244, 0.0222]
ssim_pet_values_input_laplace = [0.0164, 0.0214, 0.0210]
training_times_input_laplace = [32.05, 31.81, 31.47]
entropy_values_input_laplace = [5.5297, 5.3676, 5.3302]

# Base model metrics (shared for both Laplace and Gaussian inputs)
psnr_base_model_input = (9.2583 + 9.6965) / 2
ssim_base_model_input = (0.0412 + 0.0415) / 2
training_time_base_model_input = 31.27
entropy_base_model_input = 5.3732

# Add base model to input Laplace metrics
psnr_combined_values_with_base_input_laplace = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_input_laplace, psnr_pet_values_input_laplace)] + [psnr_base_model_input]
ssim_combined_values_with_base_input_laplace = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_input_laplace, ssim_pet_values_input_laplace)] + [ssim_base_model_input]
training_times_with_base_input_laplace = training_times_input_laplace + [training_time_base_model_input]
entropy_values_with_base_input_laplace = entropy_values_input_laplace + [entropy_base_model_input]

# Set the plot size to 10x7 for better visibility without changing individual font sizes
plt.figure(figsize=(10, 7))

# Set a color palette for the plots
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Input Laplace)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_input[:-1], y=psnr_combined_values_with_base_input_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, psnr_combined_values_with_base_input_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Input - Laplace: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_input[:-1], y=ssim_combined_values_with_base_input_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, ssim_combined_values_with_base_input_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Input - Laplace: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Input Laplace)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_input[:-1], y=entropy_values_with_base_input_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, entropy_values_with_base_input_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Input - Laplace: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_input[:-1], y=training_times_with_base_input_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, training_times_with_base_input_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Input - Laplace: Training Time vs Privacy')
plt.legend()

# Show Laplace plot with the new 10x7 size
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Input Gaussian with Base Model (Base Model at 6 as placeholder for "No Privacy")
epsilons_with_base_input = [0.1, 1, 5, 6]

# MRI-PET Input Gaussian metrics
psnr_mri_values_input_gaussian = [9.4049, 9.3445, 9.2901]
psnr_pet_values_input_gaussian = [9.5299, 9.6052, 9.6181]
ssim_mri_values_input_gaussian = [0.0402, 0.0236, 0.0236]
ssim_pet_values_input_gaussian = [0.0333, 0.0189, 0.0203]
training_times_input_gaussian = [31.94, 31.74, 31.45]
entropy_values_input_gaussian = [5.4930, 5.4908, 5.5112]

# Base model metrics (shared for both Laplace and Gaussian inputs)
psnr_base_model_input = (9.2583 + 9.6965) / 2
ssim_base_model_input = (0.0412 + 0.0415) / 2
training_time_base_model_input = 31.27
entropy_base_model_input = 5.3732

# Add base model to input Gaussian metrics
psnr_combined_values_with_base_input_gaussian = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_input_gaussian, psnr_pet_values_input_gaussian)] + [psnr_base_model_input]
ssim_combined_values_with_base_input_gaussian = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_input_gaussian, ssim_pet_values_input_gaussian)] + [ssim_base_model_input]
training_times_with_base_input_gaussian = training_times_input_gaussian + [training_time_base_model_input]
entropy_values_with_base_input_gaussian = entropy_values_input_gaussian + [entropy_base_model_input]

# Set the plot size to 10x7 for better visibility without changing individual font sizes
plt.figure(figsize=(10, 7))

# Set a color palette for the plots
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Input Gaussian)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_input[:-1], y=psnr_combined_values_with_base_input_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, psnr_combined_values_with_base_input_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Input - Gaussian: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_input[:-1], y=ssim_combined_values_with_base_input_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, ssim_combined_values_with_base_input_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Input - Gaussian: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Input Gaussian)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_input[:-1], y=entropy_values_with_base_input_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, entropy_values_with_base_input_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Input - Gaussian: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_input[:-1], y=training_times_with_base_input_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, training_times_with_base_input_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Input - Gaussian: Training Time vs Privacy')
plt.legend()

# Show Gaussian plot with the new 10x7 size
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Functional Laplace with Base Model (Base Model at 6 as placeholder for "No Privacy")
epsilons_with_base_input = [0.1, 1, 5, 6]

# MRI-PET Functional Laplace metrics
psnr_mri_values_functional_laplace = [9.0712, 9.2257, 9.3568]
psnr_pet_values_functional_laplace = [9.5098, 9.5035, 9.5518]
ssim_mri_values_functional_laplace = [0.0236, 0.0233, 0.0436]
ssim_pet_values_functional_laplace = [0.0225, 0.0183, 0.0373]
training_times_functional_laplace = [32.25, 31.23, 31.30]
entropy_values_functional_laplace = [5.3763, 5.4548, 5.4633]

# Base model metrics (shared for both Laplace and Gaussian inputs)
psnr_base_model_input = (9.2583 + 9.6965) / 2
ssim_base_model_input = (0.0412 + 0.0415) / 2
training_time_base_model_input = 31.27
entropy_base_model_input = 5.3732

# Add base model to functional Laplace metrics
psnr_combined_values_with_base_functional_laplace = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_functional_laplace, psnr_pet_values_functional_laplace)] + [psnr_base_model_input]
ssim_combined_values_with_base_functional_laplace = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_functional_laplace, ssim_pet_values_functional_laplace)] + [ssim_base_model_input]
training_times_with_base_functional_laplace = training_times_functional_laplace + [training_time_base_model_input]
entropy_values_with_base_functional_laplace = entropy_values_functional_laplace + [entropy_base_model_input]

# Set the plot size to 10x7 for better visibility without changing individual font sizes
plt.figure(figsize=(10, 7))

# Set a color palette for the plots
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Functional Laplace)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_input[:-1], y=psnr_combined_values_with_base_functional_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, psnr_combined_values_with_base_functional_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Functional Mechanism - Laplace: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_input[:-1], y=ssim_combined_values_with_base_functional_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, ssim_combined_values_with_base_functional_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Functional Mechanism - Laplace: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Functional Laplace)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_input[:-1], y=entropy_values_with_base_functional_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, entropy_values_with_base_functional_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Functional Mechanism - Laplace: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_input[:-1], y=training_times_with_base_functional_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, training_times_with_base_functional_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Functional Mechanism - Laplace: Training Time vs Privacy')
plt.legend()

# Show Functional Laplace plot with the new 10x7 size
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Functional Mechanism with Gaussian and Base Model (Base Model at 6 as placeholder for "No Privacy")
epsilons_with_base_func_gaussian = [0.1, 1, 5, 6]

# MRI-PET Functional Mechanism Gaussian metrics
psnr_mri_values_func_gaussian = [9.3334, 9.4296, 9.0763]
psnr_pet_values_func_gaussian = [9.7167, 9.5546, 9.5680]
ssim_mri_values_func_gaussian = [0.0348, 0.0250, 0.0222]
ssim_pet_values_func_gaussian = [0.0309, 0.0192, 0.0197]
training_times_func_gaussian = [32.28, 31.47, 31.25]
entropy_values_func_gaussian = [5.4256, 5.5427, 5.4068]

# Base model metrics for Functional Gaussian
psnr_base_model_func_gaussian = (9.2583 + 9.6965) / 2
ssim_base_model_func_gaussian = (0.0412 + 0.0415) / 2
training_time_base_model_func_gaussian = 31.16
entropy_base_model_func_gaussian = 5.3732

# Add base model to existing metrics
psnr_combined_values_with_base_func_gaussian = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_func_gaussian, psnr_pet_values_func_gaussian)] + [psnr_base_model_func_gaussian]
ssim_combined_values_with_base_func_gaussian = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_func_gaussian, ssim_pet_values_func_gaussian)] + [ssim_base_model_func_gaussian]
training_times_with_base_func_gaussian = training_times_func_gaussian + [training_time_base_model_func_gaussian]
entropy_values_with_base_func_gaussian = entropy_values_func_gaussian + [entropy_base_model_func_gaussian]

# Set the plot size to 10x7 for better visibility
plt.figure(figsize=(10, 7))

# Set the color palette to "rocket"
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Functional Mechanism with Gaussian)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_func_gaussian[:-1], y=psnr_combined_values_with_base_func_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, psnr_combined_values_with_base_func_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Functional Mechanism - Gaussian: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_func_gaussian[:-1], y=ssim_combined_values_with_base_func_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, ssim_combined_values_with_base_func_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Functional Mechanism - Gaussian: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Functional Mechanism with Gaussian)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_func_gaussian[:-1], y=entropy_values_with_base_func_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, entropy_values_with_base_func_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Functional Mechanism - Gaussian: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_func_gaussian[:-1], y=training_times_with_base_func_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(6, training_times_with_base_func_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Functional Mechanism - Gaussian: Training Time vs Privacy')
plt.legend()

# Show Functional Mechanism Gaussian plot with the rocket color palette
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for DP-SGD and Base Model
epsilons_with_base_dp_sgd = [0.5309, 6]  # 6 as placeholder for "Base Model"

# Metrics for DP-SGD and Base Model
entropy_dp_sgd = [7.4206, 7.4075]
mean_gradient_dp_sgd = [0.1507, 0.1457]
std_dev_dp_sgd = [0.1709, 0.1682]
spatial_freq_dp_sgd = [0.3327, 0.3237]
ssim_visible_dp_sgd = [0.0349, 0.0407]
ssim_infrared_dp_sgd = [0.0347, 0.0331]
psnr_visible_dp_sgd = [10.5683, 10.6023]
psnr_infrared_dp_sgd = [11.9198, 11.5141]
training_time_dp_sgd = [89.6171, 71.5973]
inference_time_dp_sgd = [0.1365, 0.1032]

# Combined PSNR and SSIM for DP-SGD and Base Model
psnr_combined_values_dp_sgd = [(psnr_visible_dp_sgd[0] + psnr_infrared_dp_sgd[0]) / 2, (psnr_visible_dp_sgd[1] + psnr_infrared_dp_sgd[1]) / 2]
ssim_combined_values_dp_sgd = [(ssim_visible_dp_sgd[0] + ssim_infrared_dp_sgd[0]) / 2, (ssim_visible_dp_sgd[1] + ssim_infrared_dp_sgd[1]) / 2]

# Set the plot size to 10x7 for better visibility
plt.figure(figsize=(10, 7))

# Set the color palette to summer
palette = sns.color_palette("summer")

# First row - PSNR and SSIM for DP-SGD and Base Model (both as scatter dots)
plt.subplot(2, 2, 1)
plt.scatter(0.5309, psnr_combined_values_dp_sgd[0], color='forestgreen', marker='.', s=200, label="DP-SGD")
plt.scatter(6, psnr_combined_values_dp_sgd[1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('DP-SGD: PSNR vs Base Model')
plt.legend()

plt.subplot(2, 2, 2)
plt.scatter(0.5309, ssim_combined_values_dp_sgd[0], color='forestgreen', marker='.', s=200, label="DP-SGD")
plt.scatter(6, ssim_combined_values_dp_sgd[1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('DP-SGD: SSIM vs Base Model')
plt.legend()

# Second row - Entropy and Training Time for DP-SGD and Base Model (both as scatter dots)
plt.subplot(2, 2, 3)
plt.scatter(0.5309, entropy_dp_sgd[0], color='forestgreen', marker='.', s=200, label="DP-SGD")
plt.scatter(6, entropy_dp_sgd[1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('DP-SGD: Entropy vs Base Model')
plt.legend()

plt.subplot(2, 2, 4)
plt.scatter(0.5309, training_time_dp_sgd[0], color='forestgreen', marker='.', s=200, label="DP-SGD")
plt.scatter(6, training_time_dp_sgd[1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('DP-SGD: Training Time vs Base Model')
plt.legend()

# Show DP-SGD plot with the summer color palette
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Output Laplace with Base Model (Base Model at 15 as placeholder for "No Privacy")
epsilons_with_base_output_laplace = [0.5, 5, 10, 12]

# MRI-PET Output Laplace metrics
psnr_mri_values_output_laplace = [6.3930, 8.9397, 9.4521]
psnr_pet_values_output_laplace = [5.9304, 9.2081, 9.9470]
ssim_mri_values_output_laplace = [0.0046, 0.0123, 0.0191]
ssim_pet_values_output_laplace = [0.0026, 0.0085, 0.0143]
training_times_output_laplace = [31.16, 31.16, 31.16]
entropy_values_output_laplace = [6.4297, 7.4012, 7.0173]

# Base model metrics for Output Laplace
psnr_base_model_output_laplace = (9.2583 + 9.6965) / 2
ssim_base_model_output_laplace = (0.0412 + 0.0415) / 2
training_time_base_model_output_laplace = 31.16
entropy_base_model_output_laplace = 5.3732

# Add base model to existing metrics
psnr_combined_values_with_base_output_laplace = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_output_laplace, psnr_pet_values_output_laplace)] + [psnr_base_model_output_laplace]
ssim_combined_values_with_base_output_laplace = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_output_laplace, ssim_pet_values_output_laplace)] + [ssim_base_model_output_laplace]
training_times_with_base_output_laplace = training_times_output_laplace + [training_time_base_model_output_laplace]
entropy_values_with_base_output_laplace = entropy_values_output_laplace + [entropy_base_model_output_laplace]

# Set the plot size to 10x7 for better visibility
plt.figure(figsize=(10, 7))

# Set the color palette to "rocket"
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Output Laplace)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_output_laplace[:-1], y=psnr_combined_values_with_base_output_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, psnr_combined_values_with_base_output_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Output - Laplace: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_output_laplace[:-1], y=ssim_combined_values_with_base_output_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, ssim_combined_values_with_base_output_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Output - Laplace: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Output Laplace)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_output_laplace[:-1], y=entropy_values_with_base_output_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, entropy_values_with_base_output_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Output - Laplace: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_output_laplace[:-1], y=training_times_with_base_output_laplace[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, training_times_with_base_output_laplace[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Output - Laplace: Training Time vs Privacy')
plt.legend()

# Show Output Laplace plot with the rocket color palette
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style with a light grey background
sns.set_style("darkgrid")

# Epsilon values for Output Gaussian with Base Model (Base Model at 12 as placeholder for "No Privacy")
epsilons_with_base_output_gaussian = [0.5, 5, 10, 12]

# MRI-PET Output Gaussian metrics
psnr_mri_values_output_gaussian = [6.9121, 8.6914, 9.1230]
psnr_pet_values_output_gaussian = [6.5448, 8.8559, 9.4770]
ssim_mri_values_output_gaussian = [0.0052, 0.0109, 0.0141]
ssim_pet_values_output_gaussian = [0.0029, 0.0073, 0.0098]
training_times_output_gaussian = [31.16, 31.16, 31.16]
entropy_values_output_gaussian = [7.3619, 7.5264, 7.3239]

# Base model metrics for Output Gaussian
psnr_base_model_output_gaussian = (9.2583 + 9.6965) / 2
ssim_base_model_output_gaussian = (0.0412 + 0.0415) / 2
training_time_base_model_output_gaussian = 31.16
entropy_base_model_output_gaussian = 5.3732

# Add base model to existing metrics
psnr_combined_values_with_base_output_gaussian = [(mri + pet) / 2 for mri, pet in zip(psnr_mri_values_output_gaussian, psnr_pet_values_output_gaussian)] + [psnr_base_model_output_gaussian]
ssim_combined_values_with_base_output_gaussian = [(mri + pet) / 2 for mri, pet in zip(ssim_mri_values_output_gaussian, ssim_pet_values_output_gaussian)] + [ssim_base_model_output_gaussian]
training_times_with_base_output_gaussian = training_times_output_gaussian + [training_time_base_model_output_gaussian]
entropy_values_with_base_output_gaussian = entropy_values_output_gaussian + [entropy_base_model_output_gaussian]

# Set the plot size to 10x7 for better visibility
plt.figure(figsize=(10, 7))

# Set the color palette to "rocket"
palette = sns.color_palette("rocket")

# First row - PSNR and SSIM (Output Gaussian)
plt.subplot(2, 2, 1)
sns.lineplot(x=epsilons_with_base_output_gaussian[:-1], y=psnr_combined_values_with_base_output_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, psnr_combined_values_with_base_output_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('Output - Gaussian: PSNR vs Privacy')
plt.legend()

plt.subplot(2, 2, 2)
sns.lineplot(x=epsilons_with_base_output_gaussian[:-1], y=ssim_combined_values_with_base_output_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, ssim_combined_values_with_base_output_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('Output - Gaussian: SSIM vs Privacy')
plt.legend()

# Second row - Entropy and Training Time (Output Gaussian)
plt.subplot(2, 2, 3)
sns.lineplot(x=epsilons_with_base_output_gaussian[:-1], y=entropy_values_with_base_output_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, entropy_values_with_base_output_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Entropy')
plt.title('Output - Gaussian: Entropy vs Privacy')
plt.legend()

plt.subplot(2, 2, 4)
sns.lineplot(x=epsilons_with_base_output_gaussian[:-1], y=training_times_with_base_output_gaussian[:-1], marker='o', color=palette[1], label="With Privacy")
plt.scatter(12, training_times_with_base_output_gaussian[-1], color='gray', marker='.', s=200, label="Base Model (No Privacy)")
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Output - Gaussian: Training Time vs Privacy')
plt.legend()

# Show Output Gaussian plot with the rocket color palette
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Combined metrics for Input Laplace, Input Gaussian, Functional Mechanism, and Output Mechanisms

# Mean Gradient values for all mechanisms
mg_values_input_laplace = [0.0542, 0.0513, 0.0499]
mg_values_input_gaussian = [0.0522, 0.0541, 0.0536]
mg_values_func_laplace = [0.0484, 0.0508, 0.0508]
mg_values_func_gaussian = [0.0531, 0.0544, 0.0536]
mg_values_output_laplace = [0.2788, 0.1340, 0.0823]
mg_values_output_gaussian = [0.2556, 0.1563, 0.1219]

# Standard Deviation values for all mechanisms
sd_values_input_laplace = [0.1272, 0.1360, 0.1279]
sd_values_input_gaussian = [0.1347, 0.1330, 0.1341]
sd_values_func_laplace = [0.1272, 0.1356, 0.1377]
sd_values_func_gaussian = [0.1350, 0.1323, 0.1299]
sd_values_output_laplace = [0.3073, 0.1726, 0.1307]
sd_values_output_gaussian = [0.2844, 0.1913, 0.1614]

# Spatial Frequency values for all mechanisms
sf_values_input_laplace = [0.1469, 0.1391, 0.1355]
sf_values_input_gaussian = [0.1366, 0.1459, 0.1455]
sf_values_func_laplace = [0.1319, 0.1362, 0.1342]
sf_values_func_gaussian = [0.1439, 0.1438, 0.1440]
sf_values_output_laplace = [0.6131, 0.2993, 0.1790]
sf_values_output_gaussian = [0.5637, 0.3467, 0.2682]

# PSNR values for all mechanisms
psnr_values_input_laplace = [9.3095, 9.1002, 9.1666]
psnr_values_input_gaussian = [9.4049, 9.3445, 9.2901]
psnr_values_func_laplace = [9.0712, 9.2257, 9.3568]
psnr_values_func_gaussian = [9.3334, 9.4296, 9.0763]
psnr_values_output_laplace = [6.3930, 8.9397, 9.4521]
psnr_values_output_gaussian = [6.9121, 8.6914, 9.1230]

# SSIM values for all mechanisms
ssim_values_input_laplace = [0.0235, 0.0244, 0.0222]
ssim_values_input_gaussian = [0.0402, 0.0236, 0.0236]
ssim_values_func_laplace = [0.0236, 0.0233, 0.0436]
ssim_values_func_gaussian = [0.0348, 0.0250, 0.0222]
ssim_values_output_laplace = [0.0046, 0.0123, 0.0191]
ssim_values_output_gaussian = [0.0052, 0.0109, 0.0141]

# Training times for all mechanisms (using base model training times for output mechanisms)
training_times_input_laplace = [31.28, 31.47, 31.05]
training_times_input_gaussian = [31.54, 31.44, 31.45]
training_times_func_laplace = [32.25, 31.23, 31.30]
training_times_func_gaussian = [32.28, 31.47, 31.25]
training_times_output = [31.16, 31.16, 31.16]  # Same for both output Laplace and Gaussian

# Epsilon values for Input Laplace, Input Gaussian, Functional Mechanism, and Output Mechanisms
epsilons_input = [0.1, 1, 5]
epsilons_func = [0.1, 1, 5]
epsilons_output = [0.5, 5, 10]

# Set the plot size to 12x18 for better visibility of all metrics
plt.figure(figsize=(12, 18))

# Set the color palette for multiple mechanisms
palette = sns.color_palette("inferno_r", 6)

# Mean Gradient (MG)
plt.subplot(3, 2, 1)
sns.lineplot(x=epsilons_input, y=mg_values_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=mg_values_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=mg_values_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=mg_values_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=mg_values_output_laplace, marker='o', label="Output Laplace", color=palette[4])
sns.lineplot(x=epsilons_output, y=mg_values_output_gaussian, marker='o', label="Output Gaussian", color=palette[5])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Mean Gradient (MG)')
plt.title('Mean Gradient vs Privacy')
plt.legend()

# Standard Deviation (SD)
plt.subplot(3, 2, 2)
sns.lineplot(x=epsilons_input, y=sd_values_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=sd_values_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=sd_values_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=sd_values_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=sd_values_output_laplace, marker='o', label="Output Laplace", color=palette[4])
sns.lineplot(x=epsilons_output, y=sd_values_output_gaussian, marker='o', label="Output Gaussian", color=palette[5])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Standard Deviation (SD)')
plt.title('Standard Deviation vs Privacy')
plt.legend()

# Spatial Frequency (SF)
plt.subplot(3, 2, 3)
sns.lineplot(x=epsilons_input, y=sf_values_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=sf_values_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=sf_values_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=sf_values_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=sf_values_output_laplace, marker='o', label="Output Laplace", color=palette[4])
sns.lineplot(x=epsilons_output, y=sf_values_output_gaussian, marker='o', label="Output Gaussian", color=palette[5])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Spatial Frequency (SF)')
plt.title('Spatial Frequency vs Privacy')
plt.legend()

# PSNR
plt.subplot(3, 2, 4)
sns.lineplot(x=epsilons_input, y=psnr_values_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=psnr_values_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=psnr_values_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=psnr_values_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=psnr_values_output_laplace, marker='o', label="Output Laplace", color=palette[4])
sns.lineplot(x=epsilons_output, y=psnr_values_output_gaussian, marker='o', label="Output Gaussian", color=palette[5])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('PSNR (dB)')
plt.title('PSNR vs Privacy')
plt.legend()

# SSIM
plt.subplot(3, 2, 5)
sns.lineplot(x=epsilons_input, y=ssim_values_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=ssim_values_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=ssim_values_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=ssim_values_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=ssim_values_output_laplace, marker='o', label="Output Laplace", color=palette[4])
sns.lineplot(x=epsilons_output, y=ssim_values_output_gaussian, marker='o', label="Output Gaussian", color=palette[5])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('SSIM')
plt.title('SSIM vs Privacy')
plt.legend()

# Training Time
plt.subplot(3, 2, 6)
sns.lineplot(x=epsilons_input, y=training_times_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=training_times_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=training_times_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=training_times_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=training_times_output, marker='o', label="Output Mechanisms", color=palette[4])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Training Time vs Privacy')
plt.legend()

# Show combined plot with all metrics and mechanisms
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Updated data from the table for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training\nTime (min)']
privacy_levels = ['Base Model (no $\epsilon$)', r'$\epsilon = 0.1$', r'$\epsilon = 1$', r'$\epsilon = 5$']
data = [
    [7.4075, 7.3744, 7.4606, 7.4447],  # EN
    [0.1457, 0.1409, 0.1539, 0.1581],  # MG
    [0.1682, 0.1670, 0.1762, 0.1787],  # SD
    [(10.6023 + 11.5141) / 2, (10.2958 + 11.9577) / 2, (10.5223 + 11.0277) / 2, (10.4277 + 10.8052) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0417 + 0.0381) / 2, (0.0298 + 0.0286) / 2, (0.0300 + 0.0266) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.3230, 0.3501, 0.3511],  # SF
    [71.5973, 71.8085, 71.6162, 71.4706],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Input - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the table for the Gaussian mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.1$', r'$\epsilon = 1$', r'$\epsilon = 5$']
data = [
    [7.4075, 7.4453, 7.4479, 7.4085],  # EN
    [0.1457, 0.1495, 0.1476, 0.1472],  # MG
    [0.1682, 0.1769, 0.1748, 0.1701],  # SD
    [(10.6023 + 11.5141) / 2, (10.2038 + 11.1293) / 2, (10.8918 + 11.6531) / 2, (9.7947 + 11.0280) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0361 + 0.0298) / 2, (0.0347 + 0.0316) / 2, (0.0343 + 0.0338) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.3357, 0.3431, 0.3298],  # SF
    [71.5973, 72.1941, 71.7239, 72.9088],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Input - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the table for the Functional Mechanism with Laplace noise
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.1$', r'$\epsilon = 1$', r'$\epsilon = 5$']
data = [
    [7.4075, 7.4062, 7.4333, 7.3939],  # EN
    [0.1457, 0.1414, 0.1443, 0.1437],  # MG
    [0.1682, 0.1717, 0.1728, 0.1703],  # SD
    [(10.6023 + 11.5141) / 2, (9.8320 + 11.1267) / 2, (10.6932 + 11.6699) / 2, (9.8711 + 11.8686) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0386 + 0.0342) / 2, (0.0332 + 0.0336) / 2, (0.0354 + 0.0359) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.3262, 0.3340, 0.3340],  # SF
    [71.5973, 15.4613, 15.5949, 15.5253],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Functional Mechanism - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data from the table for the Functional Mechanism with Gaussian noise
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.1$', r'$\epsilon = 1$', r'$\epsilon = 5$']
data = [
    [7.4075, 7.2914, 7.4374, 7.4390],  # EN
    [0.1457, 0.1387, 0.1469, 0.1440],  # MG
    [0.1682, 0.1606, 0.1725, 0.1733],  # SD
    [(10.6023 + 11.5141) / 2, (9.9303 + 11.0205) / 2, (10.3508 + 11.6997) / 2, (10.3623 + 10.8107) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0449 + 0.0385) / 2, (0.0363 + 0.0346) / 2, (0.0338 + 0.0312) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.3097, 0.3366, 0.3419],  # SF
    [71.5973, 15.5436, 15.6134, 15.5048],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Functional Mechanism - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Updated data from the table for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training\nTime (min)']
privacy_levels = ['Base Model (no $\epsilon$)', 'DP-SGD ($\epsilon = 0.5309$)']
data = [
    [7.4075, 7.4206],  # EN
    [0.1457, 0.1507],  # MG
    [0.1682, 0.1709],  # SD
    [11.0582, 11.2441],  # PSNR (combined vis and inf)
    [0.0369, 0.0348],  # SSIM (combined vis and inf)
    [0.3237, 0.3327],  # SF
    [71.5973, 89.6171],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('DP-SGD - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [7.4075, 3.2626, 7.4766, 7.6247],  # EN
    [0.1457, 0.4083, 0.2433, 0.1859],  # MG
    [0.1682, 0.4611, 0.2724, 0.2112],  # SD
    [(10.6023 + 11.5141) / 2, (5.6803 + 6.0263) / 2, (8.7048 + 9.3330) / 2, (9.8067 + 10.5819) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0038 + 0.0037) / 2, (0.0120 + 0.0107) / 2, (0.0216 + 0.0186) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.9220, 0.5397, 0.4138],  # SF
    [71.5973, 71.5973, 71.5973, 71.5973],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Output - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [7.4075, 4.5690, 7.3225, 7.6159],  # EN
    [0.1457, 0.3856, 0.2728, 0.2313],  # MG
    [0.1682, 0.4300, 0.3030, 0.2587],  # SD
    [(10.6023 + 11.5141) / 2, (6.1423 + 6.5178) / 2, (8.1692 + 8.7341) / 2, (8.9416 + 9.5922) / 2],  # PSNR (combined vis and inf)
    [(0.0407 + 0.0331) / 2, (0.0044 + 0.0042) / 2, (0.0095 + 0.0086) / 2, (0.0137 + 0.0119) / 2],  # SSIM (combined vis and inf)
    [0.3237, 0.8596, 0.6023, 0.5116],  # SF
    [71.5973, 71.5973, 71.5973, 71.5973],  # Training Time (min)
]

color = 'green'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Output - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Correct data for all metrics
en_values_input_laplace = [7.3744, 7.4606, 7.4447]
en_values_input_gaussian = [7.4453, 7.4479, 7.4085]
en_values_func_laplace = [7.4062, 7.4333, 7.3939]
en_values_func_gaussian = [7.2914, 7.4374, 7.4390]
en_values_output_laplace = [3.2626, 7.4766, 7.6247]
en_values_output_gaussian = [4.5690, 7.3225, 7.6159]
en_value_dpsgd = [7.4206]

mg_values_input_laplace = [0.1409, 0.1539, 0.1581]
mg_values_input_gaussian = [0.1495, 0.1476, 0.1472]
mg_values_func_laplace = [0.1414, 0.1443, 0.1437]
mg_values_func_gaussian = [0.1387, 0.1469, 0.1440]
mg_values_output_laplace = [0.4083, 0.2433, 0.1859]
mg_values_output_gaussian = [0.3856, 0.2728, 0.2313]
mg_value_dpsgd = [0.1507]

sd_values_input_laplace = [0.1670, 0.1762, 0.1787]
sd_values_input_gaussian = [0.1769, 0.1748, 0.1701]
sd_values_func_laplace = [0.1717, 0.1728, 0.1703]
sd_values_func_gaussian = [0.1606, 0.1725, 0.1733]
sd_values_output_laplace = [0.4611, 0.2724, 0.2112]
sd_values_output_gaussian = [0.4300, 0.3030, 0.2587]
sd_value_dpsgd = [0.1709]

sf_values_input_laplace = [0.3230, 0.3501, 0.3511]
sf_values_input_gaussian = [0.3357, 0.3431, 0.3298]
sf_values_func_laplace = [0.3262, 0.3340, 0.3340]
sf_values_func_gaussian = [0.3097, 0.3366, 0.3419]
sf_values_output_laplace = [0.9220, 0.5397, 0.4138]
sf_values_output_gaussian = [0.8596, 0.6023, 0.5116]
sf_value_dpsgd = [0.3327]

psnr_values_input_laplace = [11.1268, 10.7750, 10.6165]
psnr_values_input_gaussian = [10.6666, 11.2725, 10.4114]
psnr_values_func_laplace = [10.4793, 11.1816, 10.8699]
psnr_values_func_gaussian = [10.4754, 11.0253, 10.5865]
psnr_values_output_laplace = [5.8533, 9.0189, 10.1943]
psnr_values_output_gaussian = [6.3301, 8.4517, 9.2669]
psnr_value_dpsgd = [11.2441]

ssim_values_input_laplace = [0.0399, 0.0292, 0.0283]
ssim_values_input_gaussian = [0.0329, 0.0332, 0.0341]
ssim_values_func_laplace = [0.0364, 0.0334, 0.0356]
ssim_values_func_gaussian = [0.0417, 0.0355, 0.0325]
ssim_values_output_laplace = [0.0037, 0.0114, 0.0201]
ssim_values_output_gaussian = [0.0043, 0.0090, 0.0128]
ssim_value_dpsgd = [0.0348]

training_times_input_laplace = [71.8085, 71.6162, 71.4706]
training_times_input_gaussian = [72.1941, 71.7239, 72.9088]
training_times_func_laplace = [15.4613, 15.5949, 15.5253]
training_times_func_gaussian = [15.5436, 15.6134, 15.5048]
training_times_output = [71.5973, 71.5973, 71.5973]  # Same for both output Laplace and Gaussian
training_time_dpsgd = [89.6171]

# Epsilon values
epsilons_input = [0.1, 1, 5]
epsilons_func = [0.1, 1, 5]
epsilons_output = [0.5, 5, 10]
epsilon_dpsgd = [0.5309]

# Set the plot size
plt.figure(figsize=(15, 18))

# Set the color palette
palette = sns.color_palette("inferno_r", 7)

# Function to plot each metric
def plot_metric(subplot, values, ylabel, title):
    plt.subplot(subplot)
    sns.lineplot(x=epsilons_input, y=values[0], marker='o', label="Input Laplace", color=palette[0])
    sns.lineplot(x=epsilons_input, y=values[1], marker='o', label="Input Gaussian", color=palette[1])
    sns.lineplot(x=epsilons_func, y=values[2], marker='o', label="Functional Laplace", color=palette[2])
    sns.lineplot(x=epsilons_func, y=values[3], marker='o', label="Functional Gaussian", color=palette[3])
    sns.lineplot(x=epsilons_output, y=values[4], marker='o', label="Output Laplace", color=palette[4])
    sns.lineplot(x=epsilons_output, y=values[5], marker='o', label="Output Gaussian", color=palette[5])
    plt.scatter(epsilon_dpsgd, values[6], marker='s', s=100, label="DP-SGD", color=palette[6])
    plt.xlabel('Epsilon (Privacy)')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()

# Plot all metrics
plot_metric(331, [en_values_input_laplace, en_values_input_gaussian, en_values_func_laplace, 
                  en_values_func_gaussian, en_values_output_laplace, en_values_output_gaussian, en_value_dpsgd], 
            'Entropy (EN)', 'Entropy vs Privacy')

plot_metric(332, [mg_values_input_laplace, mg_values_input_gaussian, mg_values_func_laplace, 
                  mg_values_func_gaussian, mg_values_output_laplace, mg_values_output_gaussian, mg_value_dpsgd], 
            'Mean Gradient (MG)', 'Mean Gradient vs Privacy')

plot_metric(333, [sd_values_input_laplace, sd_values_input_gaussian, sd_values_func_laplace, 
                  sd_values_func_gaussian, sd_values_output_laplace, sd_values_output_gaussian, sd_value_dpsgd],
            'Standard Deviation (SD)', 'Standard Deviation vs Privacy')

plot_metric(334, [sf_values_input_laplace, sf_values_input_gaussian, sf_values_func_laplace, 
                  sf_values_func_gaussian, sf_values_output_laplace, sf_values_output_gaussian, sf_value_dpsgd],
            'Spatial Frequency (SF)', 'Spatial Frequency vs Privacy')

plot_metric(335, [psnr_values_input_laplace, psnr_values_input_gaussian, psnr_values_func_laplace, 
                  psnr_values_func_gaussian, psnr_values_output_laplace, psnr_values_output_gaussian, psnr_value_dpsgd],
            'PSNR (dB)', 'PSNR vs Privacy')

plot_metric(336, [ssim_values_input_laplace, ssim_values_input_gaussian, ssim_values_func_laplace, 
                  ssim_values_func_gaussian, ssim_values_output_laplace, ssim_values_output_gaussian, ssim_value_dpsgd],
            'SSIM', 'SSIM vs Privacy')

# Training Time
plt.subplot(337)
sns.lineplot(x=epsilons_input, y=training_times_input_laplace, marker='o', label="Input Laplace", color=palette[0])
sns.lineplot(x=epsilons_input, y=training_times_input_gaussian, marker='o', label="Input Gaussian", color=palette[1])
sns.lineplot(x=epsilons_func, y=training_times_func_laplace, marker='o', label="Functional Laplace", color=palette[2])
sns.lineplot(x=epsilons_func, y=training_times_func_gaussian, marker='o', label="Functional Gaussian", color=palette[3])
sns.lineplot(x=epsilons_output, y=training_times_output, marker='o', label="Output Mechanisms", color=palette[4])
plt.scatter(epsilon_dpsgd, training_time_dpsgd, marker='s', s=100, label="DP-SGD", color=palette[6])
plt.xlabel('Epsilon (Privacy)')
plt.ylabel('Training Time (minutes)')
plt.title('Training Time vs Privacy')
plt.legend()

# Show combined plot with all metrics and mechanisms
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 5.5297, 5.3676, 5.3302],  # EN (bits)
    [0.0497, 0.0542, 0.0513, 0.0499],  # MG
    [0.1322, 0.1272, 0.1360, 0.1279],  # SD
    [9.4774, 9.3770, 9.3814, 9.4958],  # PSNR (dB)
    [0.04135, 0.01995, 0.0229, 0.0216],  # SSIM
    [0.1332, 0.1469, 0.1391, 0.1355],  # SF
    [31.27, 32.08, 31.80, 31.47],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Input - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 5.4930, 5.4908, 5.5112],  # EN (bits)
    [0.0497, 0.0522, 0.0541, 0.0536],  # MG
    [0.1322, 0.1347, 0.1330, 0.1341],  # SD
    [0.1332, 0.1366, 0.1459, 0.1455],  # SF
    [9.4774, 9.4674, 9.4748, 9.4541],  # PSNR (dB)
    [0.04135, 0.03675, 0.02125, 0.02195],  # SSIM
    [31.27, 31.90, 31.74, 31.75],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Input - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 5.3763, 5.4548, 5.4633],  # EN (bits)
    [0.0497, 0.0484, 0.0508, 0.0508],  # MG
    [0.1322, 0.1272, 0.1356, 0.1377],  # SD
    [9.4774, 9.2905, 9.3646, 9.4543],  # PSNR (dB)
    [0.04135, 0.02305, 0.0208, 0.04045],  # SSIM
    [0.1332, 0.1319, 0.1362, 0.1342],  # SF
    [31.27, 32.42, 31.40, 31.51],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Functional Mechanism - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 5.4256, 5.5427, 5.4068],  # EN (bits)
    [0.0497, 0.0531, 0.0544, 0.0536],  # MG
    [0.1322, 0.1350, 0.1323, 0.1299],  # SD
    [9.4774, 9.52505, 9.4921, 9.32215],  # PSNR (dB)
    [0.04135, 0.03285, 0.0221, 0.02095],  # SSIM
    [0.1332, 0.1439, 0.1438, 0.1440],  # SF
    [31.27, 32.47, 31.79, 31.42],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Functional Mechanism - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 6.4297, 7.4012, 7.0173],  # EN (bits)
    [0.0497, 0.2788, 0.1340, 0.0823],  # MG
    [0.1322, 0.3073, 0.1726, 0.1307],  # SD
    [9.4774, 6.1615, 9.0739, 9.69955],  # PSNR (dB)
    [0.04135, 0.0036, 0.0104, 0.0167],  # SSIM
    [0.1332, 0.6131, 0.2993, 0.1790],  # SF
    [31.27, 31.27, 31.27, 31.27],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Output - Laplace - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for the Laplace mechanism with combined PSNR, SSIM, and Training Time
metrics = ['EN (bits)', 'MG', 'SD', 'PSNR (dB)', 'SSIM', 'SF', 'Training Time (min)']
privacy_levels = ['Base Model', r'$\epsilon = 0.5$', r'$\epsilon = 5$', r'$\epsilon = 10$']
data = [
    [5.3732, 7.3619, 7.5264, 7.3239],  # EN (bits)
    [0.0497, 0.2556, 0.1563, 0.1219],  # MG
    [0.1322, 0.2844, 0.1913, 0.1614],  # SD
    [9.4774, 6.7285, 8.77365, 9.3000],  # PSNR (dB)
    [0.04135, 0.00405, 0.0091, 0.01195],  # SSIM
    [0.1332, 0.5637, 0.3467, 0.2682],  # SF
    [31.27, 31.27, 31.27, 31.27],  # Training Time (min)
]

color = 'steelblue'

# Create subplots
fig, axes = plt.subplots(len(metrics), 1, figsize=(8, 7), sharex=True)

for i, metric in enumerate(metrics):
    axes[i].plot(privacy_levels, data[i], marker='.', color=color)
    axes[i].set_ylabel(metric, labelpad=20)  # Justify y-labels to the left
    axes[i].yaxis.set_label_coords(-0.1, 0.5)  # Adjust label position further left
    axes[i].grid(True)

# Set title and overall labels
axes[0].set_title('Output - Gaussian - Utility Metrics vs Privacy')
plt.xlabel('Privacy Levels')
plt.tight_layout()

# Show plot
plt.show()
